# %%
import pandas as pd
import yaml
import json
import os
from icecream import ic
import re

# %%
def convert_yml_json(yml_path):

    # Read YAML content from the file
    with open(yml_path, "r") as file:
        yaml_content = yaml.safe_load(file)


    # Convert to JSON
    json_output = json.dumps(yaml_content, indent=2)

    # Save to a file (optional)
    with open("output.json", "w") as json_file:
        json_file.write(json_output)

    return json_output

def check_intents_domain(domain_path):
    intent_list = []
    # Read YAML content from the file
    for file in os.listdir(domain_path):
        if "intent" in file and file.endswith(".yml"):
            intent_file = os.path.join(domain_path, file)
            # Check if the file has a .yml extension
            with open(intent_file, "r") as file:
                domain_content = yaml.safe_load(file)
                temp = domain_content.get("intents")
                intent_list.extend(temp)
        
    
    return intent_list

def check_intents_nlu(nlu_path):
    list_dict = []
    # Iterate over all files in the directory
    for nlu_file in os.listdir(nlu_path):
        # Check if the file has a .yml extension
        if nlu_file.endswith(".yml"):
            # Construct the full file path
            file_path = os.path.join(nlu_path, nlu_file)  
            # Read YAML content from the file
            with open(file_path, "r") as file:
                nlu_content = yaml.safe_load(file)
            intents_nlu = nlu_content.get("nlu")
            intents_nlu = [intent.get("intent") for intent in intents_nlu]
            list_dict.append({intent : {"file" : nlu_file} for intent in intents_nlu})
    #transform list of dictionaries to a single dictionary
    result = {}
    for dictionary in list_dict:
        result.update(dictionary)
   
    return result




def check_intent_responses(domain_path):
    # get intents from domain
    intents_domain = check_intents_domain(domain_path)
    
    intent_in_responses = {}
    # Read YAML content from the file
    for file in os.listdir(domain_path):
        if "response" in file and file.endswith(".yml"):
            file_path = os.path.join(domain_path, file)
            with open(file_path, "r") as file:
                domain_content = yaml.safe_load(file)

            # # Get intents from domain
            # intents_domain = domain_content.get("intents")
            
            # Get responses from domain
            responses_domain = domain_content.get("responses")
            # ic(responses_domain)

            # Get the responses names
            responses_names = list(responses_domain.keys())
            
            #match intents with responses
            
            for intent in intents_domain:
                if "utter_" + intent in responses_names:
                    intent_in_responses[intent] = {"action" : "utter_" + intent,
                                                "type" : "response",
                                                "file": os.path.basename(file_path)}
            buttons_actions = {}
            #match actions and buttons in responses
            i = 0
            for response in responses_domain:
                if "buttons" in responses_domain.get(response)[0].keys():
                    # ic(response)
                    # ic(responses_domain.get(response)[0].get("buttons"))
                    for button in responses_domain.get(response)[0].get("buttons"):
                        # ic(button)
                        buttons_actions[button.get("payload").strip("/")] = {"intent": response}
            
    
    df_intent = pd.DataFrame(intent_in_responses).T.reset_index()
    df_intent.columns = ["intent", "action", "type", "file"]

    return df_intent, buttons_actions

def check_intent_rules(rules_path):
    #iterate over the rules files in rules folder:
    intent_rules = {}
    # Iterate over all files in the directory
    for rule_file in os.listdir(rules_path):
        # Check if the file has a .yml extension
        if rule_file.endswith(".yml"):
            # Construct the full file path
            file_path = os.path.join(rules_path, rule_file)
            # Read YAML content from the file
            with open(file_path, "r") as file:
                rules_content = yaml.safe_load(file)
            # extract intent and related actions from rules
            rules_content = rules_content.get("rules")
            
            for rule in rules_content:
                intent = rule.get("steps")[0].get("intent")
                actions = rule.get("steps")[1].get("action")
                intent_rules[intent] = {"action" : actions,
                                    "type" : "rule",
                                    "reference" : rule.get("rule"),
                                    "file" : rule_file}
        df_intent = pd.concat([pd.DataFrame(intent_rules).T]).reset_index()
        df_intent.columns = ["intent", "action", "type", "reference", "file"]
        return df_intent

def check_intent_stories(stories_path):
    intent_stories = {}
    #iterate over the stories files in stories folder:
    # Iterate over all files in the directory
    for stories_file in os.listdir(stories_path):
        # ic(stories_file)
        # Check if the file has a .yml extension
        if stories_file.endswith(".yml"):
            # Construct the full file path
            file_path = os.path.join(stories_path, stories_file)
            # ic(file_path)
            # Read YAML content from the file
            with open(file_path, "r") as file:
                stories_content = yaml.safe_load(file)
            
            stories_content = stories_content.get("stories")
            #extract intent and related actions from each story in stories
            for story in stories_content:
                # ic(story.get("steps"), len(story.get("steps")))
                i=0
                while i < len(story.get("steps")):
                    # ic(i)
                    if "intent" in story.get("steps")[i]:
                        intent = story.get("steps")[i].get("intent")
                        # ic(intent)
                        list_actions = []
                        j = 1
                        if i + j < len(story.get("steps")):
                            while i + j < len(story.get("steps")) and "intent" not in story.get("steps")[i+j]:
                                if "action" in story.get("steps")[i+j]:
                                    list_actions.append(story.get("steps")[i+j].get("action"))
                                j += 1
                        if len(list_actions) > 0:
                            for action in list_actions:
                                intent_stories[intent] = {"action" : action,
                                                        "type" : "story",
                                                        "reference" : story.get("story"),
                                                        "file" : stories_file}
                        else:
                            intent_stories[intent] = {"action" : None,
                                                        "type" : "story",
                                                        "reference" : story.get("story"),
                                                        "file" : stories_file}
                        # ic(intent_stories)
                        i+=j
                    else:
                        i+=1          
        
    df_intent =  pd.DataFrame(intent_stories).T.reset_index()
    df_intent.columns = ["intent", "action", "type", "reference", "file"]
    
    return df_intent

def check_action_responses_in_actions(folder_path):
    #initiate the values
    current_class = None  # Keeps track of the current class
    action_name = None  # Keeps track of the current action
    actions = []
    slots = []
    intents = []
    responses = []
    payloads = []
    for file in os.listdir(folder_path):
        if "actions" in file and file.endswith(".py"):
            file_path = os.path.join(folder_path, file)
            
            with open(file_path, "r") as file:
                lines = file.readlines()
                
                file_name = os.path.basename(file_path)

                # Loop through all lines in the file
                with open(file_path, "r") as file:
                    lines = file.readlines()
                i=0
                j=0
                while i<len(lines):
                    line = lines[i]
                    
                    # Check if the line defines the class name
                    if line.startswith("class ") and "Action" in line:
                        # Extract class name
                        class_name = line.split()[1].strip().removeprefix("Action").replace(":", "")
                        if current_class != class_name:
                            if current_class and action_name:
                                # Add action to dictionary when changing class
                                temp = {"action": action_name,
                                    "class": current_class,
                                    "action_story": current_story,
                                    "action_response": responses,
                                    "action_file": file_name,
                                    "action_intent": list(set(intents)),
                                    "action_slots": list(set(slots)),
                                    "action_payload": list(set(payloads))
                                    }
                                actions.append(temp) #add the action to the list of actions

                            # reset all values that includes the case when current_class is None
                            current_class = class_name
                            current_story = None # Reset story when entering a new class
                            action_name = None # Reset action when entering a new class
                            responses = [] # Reset list of responses when entering a new class
                            intents = []
                            slots = []# Reset list of intents when entering a new class
                            
                    # Check if the line defines the current story
                    elif "current_story" in line and "=" in line:

                        if line.split("=")[0].strip() == "current_story":
                            # Extract current story name
                            current_story = line.split("=")[1].strip().replace('"', '')
                            if '#' in current_story:
                                current_story = current_story.split("#")[0].strip().strip('"')
                            # Remove quotes
                            # ic(current_story)

                    # Check if the line defines the action name
                    elif line.strip().startswith("def name(self)"):
                        # Extract action name
                        action_name = lines[i+1].split("return")[1].strip().replace('"', '')

                        i+=1
                    
                    #check if the line defines the response
                    if line.strip().startswith("dispatcher.utter_message"):

                        response = None
                        temp = line.split("(")[1].split(")")[0].strip()
                        if temp.startswith('"'):
                            response = temp.strip('"')
                        elif temp.startswith("response=") or temp.startswith("response ="):
                            response = temp.split("=")[1].split('"')[1].strip()
                            # response = temp.split("=")[1].split('"')[0].strip()
                            # ic("yo", response)
                        if response:
                            responses.append(response)

                    if line.strip().startswith('if tracker.latest_message.intent.get("name")'):

                        temp = line.split("==")[1].split(")")[0].strip().strip('"')
                        intents.append(line.split("==")[1].split('":')[0].strip().strip('"'))
                    
                    if "SlotSet(" in line:
                        slots.append(line.split("SlotSet(")[1].split(",")[0].strip().strip('"'))
                    
                    if "tracker.latest_message.get('text')" in line:
                        slots.append(line.split("{")[1].split(": tracker.latest_message.get('text')")[0].strip().strip('"'))
                    
                    if '"payload":' in line:
                        # Extract the payload using regex
                        # ic(line)
                        match = re.search(r'"payload":\s*\'?/([^\{"\'\s]+)', line)
                        if match:
                            ic(match.group(1))
                            payloads.append(match.group(1).strip())
                        else:
                            match = re.search(r'"payload":\s*\"(/[^}]*)', line)
                            if match:
                                ic(match.group(1))
                                payloads.append(match.group(1).strip('"').strip("/"))
                            
                       
                        # payloads.append(line.split('"payload":')[1].split(",")[0].strip(\n).strip('"}').strip('"'))
                        
                    i+=1
    ic(payloads)
    df = pd.DataFrame(actions)
    # df.columns = ["action", "class", "action_story", "action_response", "action_file", "action_intent"]
    return df

def check_intent(domain_path, nlu_path, rules_path, stories_path, actions_path):
    intents_nlu = check_intents_nlu(nlu_path)
    print("nlu_done")
    intents_domain = check_intents_domain(domain_path)
    print("domain_done")
    df_rules = check_intent_rules(rules_path)
    print("rules_done")
    df_stories = check_intent_stories(stories_path)
    print("stories_done")
    df_response, button_response_dic = check_intent_responses(domain_path)
    print("response_done")
    df_actions = check_action_responses_in_actions(actions_path)
    actions_from_py_list = df_actions['action'].unique()
    print("actions_done")
    df_intent = pd.concat([df_rules, df_stories, df_response])
    list_intent_df = df_intent['intent'].unique()
    list_intents_nlu_domain = set(list(intents_nlu.keys()) + intents_domain)
    #add rows to the dataframe for intents not in rules, stories and responses
    list_df = [] #container to store the intents not in rules, stories and responses
    for intent in list_intents_nlu_domain:
        if intent not in list_intent_df:
            list_df.append({"intent" : intent,
                            "action" : None,
                            "type" : None,
                            "reference" : None})
    # add the actions from the actions.py file if they are not in the actions listed
    list_actions_to_add = [i for i in actions_from_py_list if i not in df_intent['action'].unique()]
    # create a dataframe for the actions not in the intents
    for action in list_actions_to_add:
        list_df.append({"intent" : None,
                        "action" : action,
                        "type" : "action",
                        "reference" : None})
    df = pd.concat([df_intent, pd.DataFrame(list_df)]).reset_index(drop=True)
    df['nlu'] = df['intent'].apply(lambda x: True if x in intents_nlu else False)
    df['nlu_file'] = df['intent'].apply(lambda x: intents_nlu.get(x).get("file") if x in intents_nlu else None)
    df['domain'] = df['intent'].apply(lambda x: True if x in intents_domain else False)
    df['button'] = df['intent'].apply(lambda x: button_response_dic[x] if x in button_response_dic.keys() else False)
    df.sort_values(by=['nlu',"intent"], inplace=True)
    date = pd.Timestamp.now().strftime("%YY%m%d")
    df = df.merge(df_actions, on="action", how="left")
    df = df.explode("action_response", ignore_index=True)
    df = df.explode("action_intent", ignore_index=True)
    df = df.explode("action_slots", ignore_index=True)
    df.to_csv(f"data/intent_check_{date}.csv", index=False)
    print(len(df))
    return df

# %%
domain_path = "domain.yml"
nlu_path = "data/nlu"
stories_path = "data/stories"
rules_path = "data/rules"
actions_path = "actions"

df = check_intent(domain_path, nlu_path, rules_path, stories_path, actions_path)

df.head(50)
# Out:
# ic| match.group(1): '/affirm"'
# ic| match.group(1): '/deny"'
# ic| match.group(1): '/exit_grievance_process"'
# ic| match.group(1): '/affirm"'
# ic| match.group(1): '/deny"'
# ic| match.group(1): '/skip"'
# ic| match.group(1): 'set_category'
# ic| match.group(1): 'set_category'
# ic| match.group(1): 'set_category'
# ic| match.group(1): 'set_category'
# ic| match.group(1): '/skip"'
# ic| match.group(1): '/validate_summary"'
# ic| match.group(1): '/edit_grievance_summary"'
# ic| match.group(1): '/skip_summary"'
# ic| match.group(1): '/restart_story{\\"restart_type\\": \\"process\\"'
# ic| match.group(1): '/restart_story{\\"restart_type\\": \\"story\\"'
# ic| match.group(1): '/main_menu"'
# ic| payloads: ['affirm',
#                'deny',
#                'exit_grievance_process',
#                'affirm',
#                'deny',
#                'skip',
#                'set_category',
#                'set_category',
#                'set_category',
#                'set_category',
#                'skip',
#                'validate_summary',
#                'edit_grievance_summary',
#                'skip_summary',
#                'restart_story{\\"restart_type\\": \\"process\\',
#                'restart_story{\\"restart_type\\": \\"story\\',
#                'main_menu']
# nlu_done
# domain_done
# rules_done
# stories_done
# response_done
# actions_done
# 61
#                      intent                          action      type  \
# 0    edit_grievance_summary   action_edit_grievance_summary     story
# 1            launch_chatbot                            None      None
# 2          provide_location                            None      None
# 3          provide_optional                            None      None
# 4             provide_phone                            None      None
# 5   provide_updated_summary              utter_ask_location     story
# 6              skip_summary              utter_ask_location     story
# 7              skip_summary              utter_skip_summary  response
# 8   start_grievance_process         action_submit_grievance     story
# 9   start_grievance_process   utter_start_grievance_process  response
# 10   submit_grievance_as_is   action_submit_grievance_as_is      rule
# 11   submit_grievance_as_is   action_submit_grievance_as_is      rule
# 12         validate_summary              utter_ask_location     story
# 13                     None                 utter_introduce      rule
# 14                     None  action_start_grievance_process    action
# 15                     None   action_capture_grievance_text    action
# 16                     None   action_capture_grievance_text    action
# 17                     None   action_capture_grievance_text    action
# 18                     None        action_validate_category    action
# 19                     None         action_validate_summary    action
# 20                     None              action_handle_skip    action
# 21                     None              action_handle_skip    action
# 22                     None      action_set_current_process    action
# 23                     None                  action_go_back    action
# 24                     None       action_show_current_story    action
# 25                     None       action_show_current_story    action
# 26                     None     action_prepopulate_location    action
# 27                     None     action_prepopulate_location    action
# 28                     None     action_prepopulate_location    action
# 29                     None     action_prepopulate_location    action
# 30                     None          validate_location_form    action
# 31                     None          validate_location_form    action
# 32                     None          validate_location_form    action
# 33                     None          validate_location_form    action
# 34                     None          validate_location_form    action
# 35                     None                 action_send_otp    action
# 36                     None                 action_send_otp    action
# 37                     None               action_verify_otp    action
# 38                     None               action_verify_otp    action
# 39                    agree         action_submit_grievance     story
# 40            bot_challenge     action_respond_to_challenge      rule
# 41                     deny                            None      None
# 42      exit_without_filing       utter_exit_without_filing     story
# 43      exit_without_filing       utter_exit_without_filing  response
# 44           file_grievance                            None      None
# 45     file_grievance_as_is                            None      None
# 46                  go_back                   utter_go_back  response
# 47                  goodbye                   utter_goodbye      rule
# 48                  goodbye                   utter_goodbye  response
# 49                    greet                 utter_introduce      rule
#
#                                             reference  \
# 0             User edits the summary of the grievance
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5             User edits the summary of the grievance
# 6             User edits the summary of the grievance
# 7                                                 NaN
# 8                        unhappy user files grievance
# 9                                                 NaN
# 10                     User files the grievance as is
# 11                     User files the grievance as is
# 12  User files a grievance with optional location ...
# 13                     Ask grievance on session start
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                            Collect contact details
# 40                          Respond to user challenge
# 41                                               None
# 42                                 unhappy user exits
# 43                                                NaN
# 44                                               None
# 45                                               None
# 46                                                NaN
# 47          Say goodbye anytime the user says goodbye
# 48                                                NaN
# 49                             Reply to user greeting
#
#                         file    nlu         nlu_file  domain  \
# 0                stories.yml  False             None    True
# 1                        NaN  False             None    True
# 2                        NaN  False             None    True
# 3                        NaN  False             None    True
# 4                        NaN  False             None    True
# 5                stories.yml  False             None    True
# 6                stories.yml  False             None    True
# 7              responses.yml  False             None    True
# 8      unhappy_and_upset.yml  False             None    True
# 9   responses_for_action.yml  False             None    True
# 10                 rules.yml  False             None    True
# 11                 rules.yml  False             None    True
# 12               stories.yml  False             None    True
# 13                 rules.yml  False             None   False
# 14                       NaN  False             None   False
# 15                       NaN  False             None   False
# 16                       NaN  False             None   False
# 17                       NaN  False             None   False
# 18                       NaN  False             None   False
# 19                       NaN  False             None   False
# 20                       NaN  False             None   False
# 21                       NaN  False             None   False
# 22                       NaN  False             None   False
# 23                       NaN  False             None   False
# 24                       NaN  False             None   False
# 25                       NaN  False             None   False
# 26                       NaN  False             None   False
# 27                       NaN  False             None   False
# 28                       NaN  False             None   False
# 29                       NaN  False             None   False
# 30                       NaN  False             None   False
# 31                       NaN  False             None   False
# 32                       NaN  False             None   False
# 33                       NaN  False             None   False
# 34                       NaN  False             None   False
# 35                       NaN  False             None   False
# 36                       NaN  False             None   False
# 37                       NaN  False             None   False
# 38                       NaN  False             None   False
# 39               stories.yml   True          nlu.yml    True
# 40                 rules.yml   True          nlu.yml    True
# 41                       NaN   True          nlu.yml    True
# 42     unhappy_and_upset.yml   True          nlu.yml    True
# 43             responses.yml   True          nlu.yml    True
# 44                       NaN   True  nlu_buttons.yml   False
# 45                       NaN   True          nlu.yml   False
# 46  responses_for_action.yml   True  nlu_buttons.yml    True
# 47                 rules.yml   True          nlu.yml    True
# 48             responses.yml   True          nlu.yml    True
# 49                 rules.yml   True          nlu.yml    True
#
#                               button  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
# 5                              False
# 6                              False
# 7                              False
# 8                              False
# 9                              False
# 10  {'intent': 'utter_mood_unhappy'}
# 11  {'intent': 'utter_mood_unhappy'}
# 12                             False
# 13                             False
# 14                             False
# 15                             False
# 16                             False
# 17                             False
# 18                             False
# 19                             False
# 20                             False
# 21                             False
# 22                             False
# 23                             False
# 24                             False
# 25                             False
# 26                             False
# 27                             False
# 28                             False
# 29                             False
# 30                             False
# 31                             False
# 32                             False
# 33                             False
# 34                             False
# 35                             False
# 36                             False
# 37                             False
# 38                             False
# 39                             False
# 40                             False
# 41                             False
# 42  {'intent': 'utter_mood_unhappy'}
# 43  {'intent': 'utter_mood_unhappy'}
# 44                             False
# 45                             False
# 46  {'intent': 'utter_mood_unhappy'}
# 47                             False
# 48                             False
# 49                             False
#
#                                          class  \
# 0                 EditGrievanceSummary(Action)
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                      SubmitGrievance(Action)
# 9                                          NaN
# 10                 SubmitGrievanceAsIs(Action)
# 11                 SubmitGrievanceAsIs(Action)
# 12                                         NaN
# 13                                         NaN
# 14               StartGrievanceProcess(Action)
# 15                CaptureGrievanceText(Action)
# 16                CaptureGrievanceText(Action)
# 17                CaptureGrievanceText(Action)
# 18                    ValidateCategory(Action)
# 19                     ValidateSummary(Action)
# 20                          HandleSkip(Action)
# 21                          HandleSkip(Action)
# 22                   SetCurrentProcess(Action)
# 23                              GoBack(Action)
# 24                    ShowCurrentStory(Action)
# 25                    ShowCurrentStory(Action)
# 26                 PrepopulateLocation(Action)
# 27                 PrepopulateLocation(Action)
# 28                 PrepopulateLocation(Action)
# 29                 PrepopulateLocation(Action)
# 30  ValidateLocationForm(FormValidationAction)
# 31  ValidateLocationForm(FormValidationAction)
# 32  ValidateLocationForm(FormValidationAction)
# 33  ValidateLocationForm(FormValidationAction)
# 34  ValidateLocationForm(FormValidationAction)
# 35                             SendOtp(Action)
# 36                             SendOtp(Action)
# 37                           VerifyOtp(Action)
# 38                           VerifyOtp(Action)
# 39                     SubmitGrievance(Action)
# 40                  RespondToChallenge(Action)
# 41                                         NaN
# 42                                         NaN
# 43                                         NaN
# 44                                         NaN
# 45                                         NaN
# 46                                         NaN
# 47                                         NaN
# 48                                         NaN
# 49                                         NaN
#
#                        action_story  \
# 0                              None
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 8                              None
# 9                               NaN
# 10                             None
# 11                             None
# 12                              NaN
# 13                              NaN
# 14                             None
# 15                             None
# 16                             None
# 17                             None
# 18                             None
# 19                             None
# 20                             None
# 21                             None
# 22               Filing a Complaint
# 23                             None
# 24  tracker.get_slot(current_story)
# 25  tracker.get_slot(current_story)
# 26                             None
# 27                             None
# 28                             None
# 29                             None
# 30                             None
# 31                             None
# 32                             None
# 33                             None
# 34                             None
# 35                             None
# 36                             None
# 37                             None
# 38                             None
# 39                             None
# 40                             None
# 41                              NaN
# 42                              NaN
# 43                              NaN
# 44                              NaN
# 45                              NaN
# 46                              NaN
# 47                              NaN
# 48                              NaN
# 49                              NaN
#
#                                action_response           action_file  \
# 0                                          NaN  grievance_actions.py
# 1                                          NaN                   NaN
# 2                                          NaN                   NaN
# 3                                          NaN                   NaN
# 4                                          NaN                   NaN
# 5                                          NaN                   NaN
# 6                                          NaN                   NaN
# 7                                          NaN                   NaN
# 8                                          NaN  grievance_actions.py
# 9                                          NaN                   NaN
# 10             utter_grievance_submitted_as_is    generic_actions.py
# 11  utter_grievance_submitted_no_details_as_is    generic_actions.py
# 12                                         NaN                   NaN
# 13                                         NaN                   NaN
# 14               utter_start_grievance_process  grievance_actions.py
# 15                                         NaN  grievance_actions.py
# 16                                         NaN  grievance_actions.py
# 17                                         NaN  grievance_actions.py
# 18                                         NaN  grievance_actions.py
# 19                                         NaN  grievance_actions.py
# 20                        utter_ask_file_as_is  grievance_actions.py
# 21                     utter_skip_confirmation  grievance_actions.py
# 22                   utter_set_current_process    generic_actions.py
# 23                               utter_go_back    generic_actions.py
# 24                    utter_show_current_story    generic_actions.py
# 25            utter_show_current_story_unknown    generic_actions.py
# 26          utter_prepopulate_location_success   location_actions.py
# 27          utter_prepopulate_location_success   location_actions.py
# 28          utter_prepopulate_location_failure   location_actions.py
# 29          utter_prepopulate_location_failure   location_actions.py
# 30                         utter_skip_province    contact_actions.py
# 31                     utter_skip_municipality    contact_actions.py
# 32                             utter_skip_ward    contact_actions.py
# 33                          utter_skip_village    contact_actions.py
# 34                          utter_skip_address    contact_actions.py
# 35                              utter_send_otp    contact_actions.py
# 36                      utter_send_otp_failure    contact_actions.py
# 37                  utter_otp_verified_success    contact_actions.py
# 38                  utter_otp_verified_failure    contact_actions.py
# 39                                         NaN  grievance_actions.py
# 40                  utter_respond_to_challenge   location_actions.py
# 41                                         NaN                   NaN
# 42                                         NaN                   NaN
# 43                                         NaN                   NaN
# 44                                         NaN                   NaN
# 45                                         NaN                   NaN
# 46                                         NaN                   NaN
# 47                                         NaN                   NaN
# 48                                         NaN                   NaN
# 49                                         NaN                   NaN
#
#    action_intent        action_slots  \
# 0            NaN                 NaN
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
# 5            NaN                 NaN
# 6            NaN                 NaN
# 7            NaN                 NaN
# 8            NaN        grievance_id
# 9            NaN                 NaN
# 10           NaN                 NaN
# 11           NaN                 NaN
# 12           NaN                 NaN
# 13           NaN                 NaN
# 14           NaN                 NaN
# 15           NaN  grievance_category
# 16           NaN   grievance_details
# 17           NaN   grievance_summary
# 18           NaN                 NaN
# 19           NaN                 NaN
# 20           NaN          skip_count
# 21           NaN          skip_count
# 22           NaN     current_process
# 23           NaN                 NaN
# 24           NaN                 NaN
# 25           NaN                 NaN
# 26           NaN            district
# 27           NaN        municipality
# 28           NaN            district
# 29           NaN        municipality
# 30          skip                 NaN
# 31          skip                 NaN
# 32          skip                 NaN
# 33          skip                 NaN
# 34          skip                 NaN
# 35           NaN                 otp
# 36           NaN                 otp
# 37           NaN        otp_verified
# 38           NaN        otp_verified
# 39           NaN        grievance_id
# 40           NaN                 NaN
# 41           NaN                 NaN
# 42           NaN                 NaN
# 43           NaN                 NaN
# 44           NaN                 NaN
# 45           NaN                 NaN
# 46           NaN                 NaN
# 47           NaN                 NaN
# 48           NaN                 NaN
# 49           NaN                 NaN
#
#                                        action_payload
# 0   [skip_summary, set_category, deny, skip, affir...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   [skip_summary, set_category, deny, skip, affir...
# 9                                                 NaN
# 10  [skip_summary, set_category, deny, skip, affir...
# 11  [skip_summary, set_category, deny, skip, affir...
# 12                                                NaN
# 13                                                NaN
# 14                                                 []
# 15             [affirm, exit_grievance_process, deny]
# 16             [affirm, exit_grievance_process, deny]
# 17             [affirm, exit_grievance_process, deny]
# 18  [set_category, deny, skip, affirm, exit_grieva...
# 19  [skip_summary, set_category, deny, skip, affir...
# 20  [skip_summary, set_category, deny, skip, affir...
# 21  [skip_summary, set_category, deny, skip, affir...
# 22  [skip_summary, set_category, deny, skip, affir...
# 23  [skip_summary, set_category, deny, skip, affir...
# 24  [skip_summary, set_category, restart_story{\"r...
# 25  [skip_summary, set_category, restart_story{\"r...
# 26  [skip_summary, set_category, restart_story{\"r...
# 27  [skip_summary, set_category, restart_story{\"r...
# 28  [skip_summary, set_category, restart_story{\"r...
# 29  [skip_summary, set_category, restart_story{\"r...
# 30  [skip_summary, set_category, restart_story{\"r...
# 31  [skip_summary, set_category, restart_story{\"r...
# 32  [skip_summary, set_category, restart_story{\"r...
# 33  [skip_summary, set_category, restart_story{\"r...
# 34  [skip_summary, set_category, restart_story{\"r...
# 35  [skip_summary, set_category, restart_story{\"r...
# 36  [skip_summary, set_category, restart_story{\"r...
# 37  [skip_summary, set_category, restart_story{\"r...
# 38  [skip_summary, set_category, restart_story{\"r...
# 39  [skip_summary, set_category, deny, skip, affir...
# 40  [skip_summary, set_category, restart_story{\"r...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
